# %%
#Replace

# %%
import pandas as pd

cs = pd.read_csv(r"C:\Users\yadav\OneDrive\Desktop\Documents\Book1.csv")

cs
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003             NaN        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015             NaN    manoj.kapoor15@example.com           NaN
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
cs.replace(to_replace= "Rohit Yadav",value="PYTHON")
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001          PYTHON      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003             NaN        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015             NaN    manoj.kapoor15@example.com           NaN
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
cs.replace([1001,1002,1003,1004,1005,1006,1007,1008,1009,1010],101)
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0     101     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1     101      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2     101             NaN        kavya.rao3@example.com  9.310475e+09
# 3     101    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4     101     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5     101       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6     101      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7     101     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015             NaN    manoj.kapoor15@example.com           NaN
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
cs.replace("[A-Z]","PYTHON",regex=True)
# Out:
#     EmpID                   EmpName                         Email  \
# 0    1001     PYTHONohit PYTHONadav      rohit.yadav1@example.com
# 1    1002      PYTHONeer PYTHONehta      meera.mehta2@example.com
# 2    1003                       NaN        kavya.rao3@example.com
# 3    1005    PYTHONachin PYTHONoshi     sachin.joshi5@example.com
# 4    1006     PYTHONikas PYTHONoshi      vikas.joshi6@example.com
# 5    1008       PYTHONahul PYTHONao        rahul.rao8@example.com
# 6    1009      PYTHONitin PYTHONyer       nitin.iyer9@example.com
# 7    1010     PYTHONachin PYTHONhah     sachin.shah10@example.com
# 8    1013      PYTHONeha PYTHONeddy      neha.reddy13@example.com
# 9    1015                       NaN    manoj.kapoor15@example.com
# 10   1016     PYTHONmit PYTHONharma     amit.sharma16@example.com
# 11   1018     PYTHONeepak PYTHONhah     deepak.shah18@example.com
# 12   1020      PYTHONitin PYTHONhan      nitin.khan20@example.com
# ...

# %%
cs.replace(1,f)
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003             NaN        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015             NaN    manoj.kapoor15@example.com           NaN
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
import numpy as np

cs = cs.replace(1, np.nan)
cs = cs.ffill()
cs.head()
# Out:
#    EmpID       EmpName                      Email         Phone  Department
# 0   1001   Rohit Yadav   rohit.yadav1@example.com  9.111268e+09       Sales
# 1   1002    Meer Mehta   meera.mehta2@example.com  9.150787e+09  Operations
# 2   1003    Meer Mehta     kavya.rao3@example.com  9.310475e+09       Sales
# 3   1005  Sachin Joshi  sachin.joshi5@example.com  9.152289e+09  Operations
# 4   1006   Vikas Joshi   vikas.joshi6@example.com  9.775118e+08   Marketing

# %%
cs = cs.replace(1, np.nan).ffill()
print(cs)
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003      Meer Mehta        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015      Neha Reddy    manoj.kapoor15@example.com  9.240042e+09
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
cs = cs.replace(1, np.nan).bfill()
print(cs)
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003      Meer Mehta        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015      Neha Reddy    manoj.kapoor15@example.com  9.240042e+09
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...
