# %%
import pandas as pd

students = {
    "Name": ["Nitu", "Rahul", "Aman"],
    "Age": [24, 25, 23],
    "City": ["Thane", "Mumbai", "Pune"]
}

df = pd.DataFrame(students)

df
# Out:
#     Name  Age    City
# 0   Nitu   24   Thane
# 1  Rahul   25  Mumbai
# 2   Aman   23    Pune

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv")
df
# Out:
#     CustomerID CustomerName  Country        State       City
# 0         1001   Customer_1  Germany   California     Austin
# 1         1002   Customer_2       UK   California  Bangalore
# 2         1003   Customer_3       UK  Maharashtra  Bangalore
# 3         1004   Customer_4      USA  Maharashtra     Mumbai
# 4         1005   Customer_5  Germany    Karnataka     Mumbai
# 5         1006   Customer_6    India        Texas     London
# 6         1007   Customer_7      USA      Bavaria     Munich
# 7         1008   Customer_8  Germany        Texas     London
# 8         1009   Customer_9    India        Texas     Munich
# 9         1010  Customer_10       UK        Texas     Munich
# 10        1011  Customer_11       UK        Texas     Austin
# 11        1012  Customer_12       UK   California     Austin
# 12        1013  Customer_13      USA  Maharashtra     Munich
# 13        1014  Customer_14      USA    Karnataka     London
# ...

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv")
df.head()
# Out:
#    CustomerID CustomerName  Country        State       City
# 0        1001   Customer_1  Germany   California     Austin
# 1        1002   Customer_2       UK   California  Bangalore
# 2        1003   Customer_3       UK  Maharashtra  Bangalore
# 3        1004   Customer_4      USA  Maharashtra     Mumbai
# 4        1005   Customer_5  Germany    Karnataka     Mumbai

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv")
df.tail()
# Out:
#     CustomerID CustomerName  Country        State       City
# 45        1046  Customer_46  Germany        Texas     Mumbai
# 46        1047  Customer_47      USA   California  Bangalore
# 47        1048  Customer_48  Germany  Maharashtra  Bangalore
# 48        1049  Customer_49  Germany   California     London
# 49        1050  Customer_50       UK   California     Austin

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv")
df.dtypes
# Out:
# CustomerID      int64
# CustomerName      str
# Country           str
# State             str
# City              str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    50 non-null     int64
#  1   CustomerName  50 non-null     str
#  2   Country       50 non-null     str
#  3   State         50 non-null     str
#  4   City          50 non-null     str
# dtypes: int64(1), str(4)
# memory usage: 2.1 KB

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv")
df.shape
# Out:
# (50, 5)

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv")
df.describe
# Out:
# <bound method NDFrame.describe of     CustomerID CustomerName  Country        State       City
# 0         1001   Customer_1  Germany   California     Austin
# 1         1002   Customer_2       UK   California  Bangalore
# 2         1003   Customer_3       UK  Maharashtra  Bangalore
# 3         1004   Customer_4      USA  Maharashtra     Mumbai
# 4         1005   Customer_5  Germany    Karnataka     Mumbai
# 5         1006   Customer_6    India        Texas     London
# 6         1007   Customer_7      USA      Bavaria     Munich
# 7         1008   Customer_8  Germany        Texas     London
# 8         1009   Customer_9    India        Texas     Munich
# 9         1010  Customer_10       UK        Texas     Munich
# 10        1011  Customer_11       UK        Texas     Austin
# 11        1012  Customer_12       UK   California     Austin
# 12        1013  Customer_13      USA  Maharashtra     Munich
# 13        1014  Customer_14      USA    Karnataka     London
# ...

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv")
df.columns
# Out:
# Index(['CustomerID', 'CustomerName', 'Country', 'State', 'City'], dtype='str')

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv",header=None)
df
# Out:
#              0             1        2            3          4
# 0   CustomerID  CustomerName  Country        State       City
# 1         1001    Customer_1  Germany   California     Austin
# 2         1002    Customer_2       UK   California  Bangalore
# 3         1003    Customer_3       UK  Maharashtra  Bangalore
# 4         1004    Customer_4      USA  Maharashtra     Mumbai
# 5         1005    Customer_5  Germany    Karnataka     Mumbai
# 6         1006    Customer_6    India        Texas     London
# 7         1007    Customer_7      USA      Bavaria     Munich
# 8         1008    Customer_8  Germany        Texas     London
# 9         1009    Customer_9    India        Texas     Munich
# 10        1010   Customer_10       UK        Texas     Munich
# 11        1011   Customer_11       UK        Texas     Austin
# 12        1012   Customer_12       UK   California     Austin
# 13        1013   Customer_13      USA  Maharashtra     Munich
# ...

# %%
df = pd.read_csv(r"C:\Users\yadav\Downloads\Customers (2).csv")
df.columns=["c_id","c_name","c_country","c_state","c_city"]
df
# Out:
#     c_id       c_name c_country      c_state     c_city
# 0   1001   Customer_1   Germany   California     Austin
# 1   1002   Customer_2        UK   California  Bangalore
# 2   1003   Customer_3        UK  Maharashtra  Bangalore
# 3   1004   Customer_4       USA  Maharashtra     Mumbai
# 4   1005   Customer_5   Germany    Karnataka     Mumbai
# 5   1006   Customer_6     India        Texas     London
# 6   1007   Customer_7       USA      Bavaria     Munich
# 7   1008   Customer_8   Germany        Texas     London
# 8   1009   Customer_9     India        Texas     Munich
# 9   1010  Customer_10        UK        Texas     Munich
# 10  1011  Customer_11        UK        Texas     Austin
# 11  1012  Customer_12        UK   California     Austin
# 12  1013  Customer_13       USA  Maharashtra     Munich
# 13  1014  Customer_14       USA    Karnataka     London
# 14  1015  Customer_15       USA    Karnataka     London
# 15  1016  Customer_16     India   California     Mumbai
# ...

# %%
col=["c_id","c_name"]
df[col]
# Out:
#     c_id       c_name
# 0   1001   Customer_1
# 1   1002   Customer_2
# 2   1003   Customer_3
# 3   1004   Customer_4
# 4   1005   Customer_5
# 5   1006   Customer_6
# 6   1007   Customer_7
# 7   1008   Customer_8
# 8   1009   Customer_9
# 9   1010  Customer_10
# 10  1011  Customer_11
# 11  1012  Customer_12
# 12  1013  Customer_13
# 13  1014  Customer_14
# 14  1015  Customer_15
# 15  1016  Customer_16
# 16  1017  Customer_17
# 17  1018  Customer_18
# 18  1019  Customer_19
# 19  1020  Customer_20
# 20  1021  Customer_21
# 21  1022  Customer_22
# 22  1023  Customer_23
# 23  1024  Customer_24
# 24  1025  Customer_25
# 25  1026  Customer_26
# 26  1027  Customer_27
# 27  1028  Customer_28
# 28  1029  Customer_29
# 29  1030  Customer_30
# 30  1031  Customer_31
# 31  1032  Customer_32
# 32  1033  Customer_33
# 33  1034  Customer_34
# 34  1035  Customer_35
# 35  1036  Customer_36
# 36  1037  Customer_37
# 37  1038  Customer_38
# 38  1039  Customer_39
# 39  1040  Customer_40
# ...

# %%
df[["c_id","c_name"]]
# Out:
#     c_id       c_name
# 0   1001   Customer_1
# 1   1002   Customer_2
# 2   1003   Customer_3
# 3   1004   Customer_4
# 4   1005   Customer_5
# 5   1006   Customer_6
# 6   1007   Customer_7
# 7   1008   Customer_8
# 8   1009   Customer_9
# 9   1010  Customer_10
# 10  1011  Customer_11
# 11  1012  Customer_12
# 12  1013  Customer_13
# 13  1014  Customer_14
# 14  1015  Customer_15
# 15  1016  Customer_16
# 16  1017  Customer_17
# 17  1018  Customer_18
# 18  1019  Customer_19
# 19  1020  Customer_20
# 20  1021  Customer_21
# 21  1022  Customer_22
# 22  1023  Customer_23
# 23  1024  Customer_24
# 24  1025  Customer_25
# 25  1026  Customer_26
# 26  1027  Customer_27
# 27  1028  Customer_28
# 28  1029  Customer_29
# 29  1030  Customer_30
# 30  1031  Customer_31
# 31  1032  Customer_32
# 32  1033  Customer_33
# 33  1034  Customer_34
# 34  1035  Customer_35
# 35  1036  Customer_36
# 36  1037  Customer_37
# 37  1038  Customer_38
# 38  1039  Customer_39
# 39  1040  Customer_40
# ...

# %%
df_new=df["c_id"]
type(df_new)
# Out:
# pandas.Series
