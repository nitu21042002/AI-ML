# %%
#Handling Missing Data (Dropna & Fillna)

# %%
import pandas as pd

cs = pd.read_csv(r"C:\Users\yadav\OneDrive\Desktop\Documents\Book1.csv")

cs
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003             NaN        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015             NaN    manoj.kapoor15@example.com           NaN
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
cs.dropna()
# Out:
#     EmpID       EmpName                       Email         Phone  Department
# 0    1001   Rohit Yadav    rohit.yadav1@example.com  9.111268e+09       Sales
# 1    1002    Meer Mehta    meera.mehta2@example.com  9.150787e+09  Operations
# 3    1005  Sachin Joshi   sachin.joshi5@example.com  9.152289e+09  Operations
# 4    1006   Vikas Joshi    vikas.joshi6@example.com  9.775118e+08   Marketing
# 5    1008     Rahul Rao      rahul.rao8@example.com  9.918615e+09       Sales
# 6    1009    Nitin Iyer     nitin.iyer9@example.com  9.407051e+09   Marketing
# 7    1010   Sachin Shah   sachin.shah10@example.com  9.553605e+09          HR
# 8    1013    Neha Reddy    neha.reddy13@example.com  9.240042e+09          IT
# 10   1016   Amit Sharma   amit.sharma16@example.com  9.688355e+09          HR
# 11   1018   Deepak Shah   deepak.shah18@example.com  9.731236e+09       Sales
# 12   1020    Nitin Khan    nitin.khan20@example.com  9.899424e+09          HR
# ...

# %%
cs.dropna(axis=1)
# Out:
#     EmpID
# 0    1001
# 1    1002
# 2    1003
# 3    1005
# 4    1006
# 5    1008
# 6    1009
# 7    1010
# 8    1013
# 9    1015
# 10   1016
# 11   1018
# 12   1020
# 13   1021
# 14   1022
# 15   1023
# 16   1024
# 17   1025
# 18   1029
# 19   1030
# 20   1031
# 21   1032
# 22   1033
# 23   1034
# 24   1035
# 25   1036

# %%
cs.dropna(axis=0)
# Out:
#     EmpID       EmpName                       Email         Phone  Department
# 0    1001   Rohit Yadav    rohit.yadav1@example.com  9.111268e+09       Sales
# 1    1002    Meer Mehta    meera.mehta2@example.com  9.150787e+09  Operations
# 3    1005  Sachin Joshi   sachin.joshi5@example.com  9.152289e+09  Operations
# 4    1006   Vikas Joshi    vikas.joshi6@example.com  9.775118e+08   Marketing
# 5    1008     Rahul Rao      rahul.rao8@example.com  9.918615e+09       Sales
# 6    1009    Nitin Iyer     nitin.iyer9@example.com  9.407051e+09   Marketing
# 7    1010   Sachin Shah   sachin.shah10@example.com  9.553605e+09          HR
# 8    1013    Neha Reddy    neha.reddy13@example.com  9.240042e+09          IT
# 10   1016   Amit Sharma   amit.sharma16@example.com  9.688355e+09          HR
# 11   1018   Deepak Shah   deepak.shah18@example.com  9.731236e+09       Sales
# 12   1020    Nitin Khan    nitin.khan20@example.com  9.899424e+09          HR
# ...

# %%
cs.dropna(how="any")
# Out:
#     EmpID       EmpName                       Email         Phone  Department
# 0    1001   Rohit Yadav    rohit.yadav1@example.com  9.111268e+09       Sales
# 1    1002    Meer Mehta    meera.mehta2@example.com  9.150787e+09  Operations
# 3    1005  Sachin Joshi   sachin.joshi5@example.com  9.152289e+09  Operations
# 4    1006   Vikas Joshi    vikas.joshi6@example.com  9.775118e+08   Marketing
# 5    1008     Rahul Rao      rahul.rao8@example.com  9.918615e+09       Sales
# 6    1009    Nitin Iyer     nitin.iyer9@example.com  9.407051e+09   Marketing
# 7    1010   Sachin Shah   sachin.shah10@example.com  9.553605e+09          HR
# 8    1013    Neha Reddy    neha.reddy13@example.com  9.240042e+09          IT
# 10   1016   Amit Sharma   amit.sharma16@example.com  9.688355e+09          HR
# 11   1018   Deepak Shah   deepak.shah18@example.com  9.731236e+09       Sales
# 12   1020    Nitin Khan    nitin.khan20@example.com  9.899424e+09          HR
# ...

# %%
cs.dropna(how="all")
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003             NaN        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015             NaN    manoj.kapoor15@example.com           NaN
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
cs.dropna(subset="EmpName")
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# 12   1020      Nitin Khan      nitin.khan20@example.com  9.899424e+09
# 14   1022      Sachin Das      sachin.das22@example.com  9.666161e+09
# ...

# %%
cs.dropna(subset=["Phone"])
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003             NaN        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# 12   1020      Nitin Khan      nitin.khan20@example.com  9.899424e+09
# ...

# %%
cs.dropna(thresh=2)
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003             NaN        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015             NaN    manoj.kapoor15@example.com           NaN
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
#Fillna

# %%
cs.fillna("NITU")
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9111268039.0
# 1    1002      Meer Mehta      meera.mehta2@example.com  9150786963.0
# 2    1003            NITU        kavya.rao3@example.com  9310474687.0
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9152289378.0
# 4    1006     Vikas Joshi      vikas.joshi6@example.com   977511850.0
# 5    1008       Rahul Rao        rahul.rao8@example.com  9918615372.0
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9407050929.0
# 7    1010     Sachin Shah     sachin.shah10@example.com  9553605379.0
# 8    1013      Neha Reddy      neha.reddy13@example.com  9240042131.0
# 9    1015            NITU    manoj.kapoor15@example.com          NITU
# 10   1016     Amit Sharma     amit.sharma16@example.com  9688355238.0
# 11   1018     Deepak Shah     deepak.shah18@example.com  9731235606.0
# ...

# %%
cs.fillna({"Phone":"YADAV"})
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9111268039.0
# 1    1002      Meer Mehta      meera.mehta2@example.com  9150786963.0
# 2    1003             NaN        kavya.rao3@example.com  9310474687.0
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9152289378.0
# 4    1006     Vikas Joshi      vikas.joshi6@example.com   977511850.0
# 5    1008       Rahul Rao        rahul.rao8@example.com  9918615372.0
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9407050929.0
# 7    1010     Sachin Shah     sachin.shah10@example.com  9553605379.0
# 8    1013      Neha Reddy      neha.reddy13@example.com  9240042131.0
# 9    1015             NaN    manoj.kapoor15@example.com         YADAV
# 10   1016     Amit Sharma     amit.sharma16@example.com  9688355238.0
# 11   1018     Deepak Shah     deepak.shah18@example.com  9731235606.0
# ...

# %%
cs.bfill()
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003    Sachin Joshi        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015     Amit Sharma    manoj.kapoor15@example.com  9.688355e+09
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
cs.ffill()
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9.111268e+09
# 1    1002      Meer Mehta      meera.mehta2@example.com  9.150787e+09
# 2    1003      Meer Mehta        kavya.rao3@example.com  9.310475e+09
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9.152289e+09
# 4    1006     Vikas Joshi      vikas.joshi6@example.com  9.775118e+08
# 5    1008       Rahul Rao        rahul.rao8@example.com  9.918615e+09
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9.407051e+09
# 7    1010     Sachin Shah     sachin.shah10@example.com  9.553605e+09
# 8    1013      Neha Reddy      neha.reddy13@example.com  9.240042e+09
# 9    1015      Neha Reddy    manoj.kapoor15@example.com  9.240042e+09
# 10   1016     Amit Sharma     amit.sharma16@example.com  9.688355e+09
# 11   1018     Deepak Shah     deepak.shah18@example.com  9.731236e+09
# ...

# %%
cs.fillna("PYTHON",limit=2)
# Out:
#     EmpID         EmpName                         Email         Phone  \
# 0    1001     Rohit Yadav      rohit.yadav1@example.com  9111268039.0
# 1    1002      Meer Mehta      meera.mehta2@example.com  9150786963.0
# 2    1003          PYTHON        kavya.rao3@example.com  9310474687.0
# 3    1005    Sachin Joshi     sachin.joshi5@example.com  9152289378.0
# 4    1006     Vikas Joshi      vikas.joshi6@example.com   977511850.0
# 5    1008       Rahul Rao        rahul.rao8@example.com  9918615372.0
# 6    1009      Nitin Iyer       nitin.iyer9@example.com  9407050929.0
# 7    1010     Sachin Shah     sachin.shah10@example.com  9553605379.0
# 8    1013      Neha Reddy      neha.reddy13@example.com  9240042131.0
# 9    1015          PYTHON    manoj.kapoor15@example.com        PYTHON
# 10   1016     Amit Sharma     amit.sharma16@example.com  9688355238.0
# 11   1018     Deepak Shah     deepak.shah18@example.com  9731235606.0
# ...
