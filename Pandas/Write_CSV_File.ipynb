# %%
#Write CSV File

# %%
import pandas as pd

dic= pd.DataFrame({"A":[1,2,3,4,5],"B":[6,7,8,9,0]})

d = pd.DataFrame(dic)

print(d)
# Out:
#    A  B
# 0  1  6
# 1  2  7
# 2  3  8
# 3  4  9
# 4  5  0

# %%
d.to_csv("nitu.csv")

# %%
d.to_csv("nitu_yadav.csv",index=False)

# %%
d.to_csv("nitu_yadav_header.csv",index=False,header=["a","b"])
